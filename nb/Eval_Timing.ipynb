# %%
import yaml
import matplotlib.pyplot as plt
import numpy as np
import pandas
from pz_data_challenge.evaluation import build_summary_data_dict, make_algo_estimate_time_strip_plot, make_algo_inform_time_strip_plot

# %%
RESULTS_DIR = '../results'
SUBMISSIONS = ['easy_forest', 'rail_knn_test', 'rail_bpz_test', 'bpz_31temps']

# %%
data_dict = build_summary_data_dict(RESULTS_DIR, SUBMISSIONS, "timing")

# %%
fig_algo_estimate_time = make_algo_estimate_time_strip_plot(
    data_dict,
    SUBMISSIONS,
)

# %%
fig_algo_inform_time = make_algo_inform_time_strip_plot(
    data_dict,
    SUBMISSIONS,
)
